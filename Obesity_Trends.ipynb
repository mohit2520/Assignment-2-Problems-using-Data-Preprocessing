# %%
# import the libraries 
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Read the csv file 
df = pd.read_csv("Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv")

# %%
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
# to see random file 
df.sample(5)
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 49915       2016     2016           RI    Rhode Island
# 13995       2013     2013           MD        Maryland
# 51127       2016     2016           NE        Nebraska
# 32367       2013     2013           VA        Virginia
# 23278       2013     2013           NC  North Carolina
#
#                                        Datasource                    Class  \
# 49915  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 13995  Behavioral Risk Factor Surveillance System        Physical Activity
# 51127  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 32367  Behavioral Risk Factor Surveillance System        Physical Activity
# 23278  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                               Topic  \
# 49915       Obesity / Weight Status
# 13995  Physical Activity - Behavior
# 51127       Obesity / Weight Status
# ...

# %%
# get the number of rows and cols
df.shape
# Out:
# (53392, 33)

# %%
# get the cols data type
df.dtypes
# Out:
# YearStart                       int64
# YearEnd                         int64
# LocationAbbr                   object
# LocationDesc                   object
# Datasource                     object
# Class                          object
# Topic                          object
# Question                       object
# Data_Value_Unit               float64
# Data_Value_Type                object
# Data_Value                    float64
# Data_Value_Alt                float64
# Data_Value_Footnote_Symbol     object
# Data_Value_Footnote            object
# Low_Confidence_Limit          float64
# High_Confidence_Limit         float64
# Sample_Size                   float64
# Total                          object
# Age(years)                     object
# Education                      object
# Gender                         object
# Income                         object
# Race/Ethnicity                 object
# GeoLocation                    object
# ClassID                        object
# ...

# %%
# get a count of the empty value for each column
df.isna().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               53392
# Data_Value_Type                   0
# Data_Value                     5046
# Data_Value_Alt                 5046
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit           5046
# High_Confidence_Limit          5046
# Sample_Size                    5046
# Total                         51485
# Age(years)                    41954
# Education                     45764
# Gender                        49578
# Income                        40043
# Race/Ethnicity                38136
# GeoLocation                    1008
# ClassID                           0
# TopicID                           0
# ...

# %%
# check for any missing /null value in data
df.isnull().values.any()
# Out:
# True

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
# Describing all the Numerical Features
df.describe()
# Out:
#           YearStart       YearEnd  Data_Value_Unit    Data_Value  \
# count  53392.000000  53392.000000              0.0  48346.000000
# mean    2013.281465   2013.281465              NaN     31.156681
# std        1.693300      1.693300              NaN     10.247033
# min     2011.000000   2011.000000              NaN      0.900000
# 25%     2012.000000   2012.000000              NaN     24.100000
# 50%     2013.000000   2013.000000              NaN     30.700000
# 75%     2015.000000   2015.000000              NaN     37.000000
# max     2016.000000   2016.000000              NaN     77.600000
#
#        Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   \
# count    48346.000000          48346.000000            48346.000000
# mean        31.156681             26.892227               35.989997
# std         10.247033             10.038584               11.205813
# min          0.900000              0.300000                3.000000
# ...

# %%
# To understand Missing values
plt.figure(figsize= (20,10))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# To get the Percentage of missing values.
np.round(((df.isnull().sum())/len(df))*100,2)
# Out:
# YearStart                       0.00
# YearEnd                         0.00
# LocationAbbr                    0.00
# LocationDesc                    0.00
# Datasource                      0.00
# Class                           0.00
# Topic                           0.00
# Question                        0.00
# Data_Value_Unit               100.00
# Data_Value_Type                 0.00
# Data_Value                      9.45
# Data_Value_Alt                  9.45
# Data_Value_Footnote_Symbol     90.55
# Data_Value_Footnote            90.55
# Low_Confidence_Limit            9.45
# High_Confidence_Limit           9.45
# Sample_Size                     9.45
# Total                          96.43
# Age(years)                     78.58
# Education                      85.71
# Gender                         92.86
# Income                         75.00
# Race/Ethnicity                 71.43
# GeoLocation                     1.89
# ClassID                         0.00
# ...

# %%
# show the data value  by age
import matplotlib.pyplot as plt
plt.subplots(figsize=(20,5))
sns.countplot(x='Data_Value' , hue='Age(years)' , data=df , palette = 'colorblind')
# Out:
# <AxesSubplot:xlabel='Data_Value', ylabel='count'>

# %%
df_new = df.drop(['Data_Value_Unit','Data_Value_Footnote_Symbol','Data_Value_Footnote','Total','Age(years)','Education','Gender'] , axis=1)

# %%
df_new
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(20,5))
sns.countplot(x='YearStart' , hue='Datasource' , data=df , palette = 'colorblind')
# Out:
# <AxesSubplot:xlabel='YearStart', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(20,5))
sns.countplot(x='YearStart' , hue='Class' , data=df , palette = 'colorblind')
# Out:
# <AxesSubplot:xlabel='YearStart', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(20,20))
sns.countplot(x='YearStart' , hue='LocationDesc' , data=df , palette = 'colorblind')
# Out:
# <AxesSubplot:xlabel='YearStart', ylabel='count'>
